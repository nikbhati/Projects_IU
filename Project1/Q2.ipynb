# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('q2.csv')

# %%
df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0            '<0'         6  'critical/other existing credit'
# 1      '0<=X<200'        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3            '<0'        42                   'existing paid'
# 4            '<0'        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'      '>=7'
# 1             radio/tv           5951              '<100'   '1<=X<4'
# 2            education           2096              '<100'   '4<=X<7'
# 3  furniture/equipment           7882              '<100'   '4<=X<7'
# 4            'new car'           4870              '<100'   '1<=X<4'
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   int64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   int64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   int64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   int64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   int64
#  13  other_payment_plans     1000 non-null   object
# ...

# %%
df.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
df.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
df.job.value_counts()
# Out:
# skilled                        630
# 'unskilled resident'           200
# 'high qualif/self emp/mgmt'    148
# 'unemp/unskilled non res'       22
# Name: job, dtype: int64

# %%
df.checking_status.value_counts()
# Out:
# 'no checking'    394
# '<0'             274
# '0<=X<200'       269
# '>=200'           63
# Name: checking_status, dtype: int64

# %%
df.credit_history.value_counts()
# Out:
# 'existing paid'                     530
# 'critical/other existing credit'    293
# 'delayed previously'                 88
# 'all paid'                           49
# 'no credits/all paid'                40
# Name: credit_history, dtype: int64

# %%
df.purpose.value_counts()
# Out:
# radio/tv                280
# 'new car'               234
# furniture/equipment     181
# 'used car'              103
# business                 97
# education                50
# repairs                  22
# 'domestic appliance'     12
# other                    12
# retraining                9
# Name: purpose, dtype: int64

# %%
df.other_parties.value_counts()
# Out:
# none              907
# guarantor          52
# 'co applicant'     41
# Name: other_parties, dtype: int64

# %%
df.installment_commitment.value_counts()
# Out:
# 4    476
# 2    231
# 3    157
# 1    136
# Name: installment_commitment, dtype: int64

# %%
df.residence_since.value_counts()
# Out:
# 4    413
# 2    308
# 3    149
# 1    130
# Name: residence_since, dtype: int64

# %%
df.num_dependents.value_counts()
# Out:
# 1    845
# 2    155
# Name: num_dependents, dtype: int64

# %%
#cat_var=df.select_dtypes(include=object).columns.to_list()

# %%
#num_var=df.select_dtypes(include=np.number).columns.to_list()

# %%
cat_var
# Out:
# ['checking_status',
#  'credit_history',
#  'purpose',
#  'savings_status',
#  'employment',
#  'personal_status',
#  'other_parties',
#  'property_magnitude',
#  'other_payment_plans',
#  'housing',
#  'job',
#  'own_telephone',
#  'foreign_worker',
#  'class']

# %%
num_var
# Out:
# ['duration',
#  'credit_amount',
#  'installment_commitment',
#  'residence_since',
#  'age',
#  'existing_credits',
#  'num_dependents']

# %%
import seaborn as sns

# %%
i=1
plt.figure(figsize=(15,20))
for j in num_var:
    plt.subplot(5,3,i)
    sns.boxplot(data=df,x=j)
    i+=1

# %%
df.isnull().sum()
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
df[['duration','credit_amount']]
# Out:
#      duration  credit_amount
# 0           6           1169
# 1          48           5951
# 2          12           2096
# 3          42           7882
# 4          24           4870
# ..        ...            ...
# 995        12           1736
# 996        30           3857
# 997        12            804
# 998        45           1845
# 999        45           4576
#
# [1000 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
# Categorical Features are 'checking_status', 'credit_history', 'purpose','savings_status', 'employment', 'installment_commitment', 'personal_status', 'other_parties',
#'residence_since', 'property_magnitude','other_payment_plans','housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#'foreign_worker', 'class'

# %%
#Continuous Variables are duration,credit_amount,age

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df.duration,df.index,hue=df['class'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='duration'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df.credit_amount,df.index,hue=df['class'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='credit_amount'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df.age,df.index,hue=df['class'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='class',data=df,hue='purpose')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
ct = ColumnTransformer(
    [("onehot", OneHotEncoder(sparse=False,handle_unknown='ignore'),['checking_status', 'credit_history', 'purpose',
        'savings_status', 'employment',
       'installment_commitment', 'personal_status', 'other_parties',
       'residence_since', 'property_magnitude', 'other_payment_plans',
       'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
       'foreign_worker'])])

# %%
from sklearn.model_selection import train_test_split

# %%
data_ft=df.drop('class',axis=1)
X_train,X_test,y_train,y_test=train_test_split(data_ft,df['class'],test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
ct.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('onehot',
#                                  OneHotEncoder(handle_unknown='ignore',
#                                                sparse=False),
#                                  ['checking_status', 'credit_history',
#                                   'purpose', 'savings_status', 'employment',
#                                   'installment_commitment', 'personal_status',
#                                   'other_parties', 'residence_since',
#                                   'property_magnitude', 'other_payment_plans',
#                                   'housing', 'existing_credits', 'job',
#                                   'num_dependents', 'own_telephone',
#                                   'foreign_worker'])])

# %%
X_train_trans=ct.transform(X_train)

# %%
lg.fit(X_train_trans,y_train)
# Out:
# LogisticRegression()

# %%
X_test_trans=ct.transform(X_test)

# %%
lg.score(X_test_trans,y_test)
# Out:
# 0.7233333333333334

# %%
from sklearn.svm import LinearSVC

# %%
mod=LinearSVC()

# %%
mod.fit(X_train_trans,y_train)
# Out:
# LinearSVC()

# %%
mod.score(X_test_trans,y_test)
# Out:
# 0.72

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train_trans,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.score(X_test_trans,y_test)
# Out:
# 0.7066666666666667
